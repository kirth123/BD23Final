# %% [markdown]
# ### This notebook constructs an asynchronous query to do a heavyduty calculation periodically and then store the resulting data (top 1000 tag categories) into a separate key-value DynamoDB data store for faster more efficient and performant retrieval for near real-time processing.
# #### This enables us to efficiently store semi-permanent data into an efficient key-value data store which is optimized for reads, and split the workload of the client facing component of the project.

# %%
import pymongo
from IPython.display import display
from pymongo import MongoClient
import pandas as pd
from dotenv import dotenv_values


config = dotenv_values(".env.local")

# setup mongo connection
client = MongoClient('mongodb+srv://' + config['MONGO_USER'] + ':' + config['MONGO_PASS'] + '@final-cluster.uucno.mongodb.net')
db = client.final
col = db.StackOverflowPosts

# %%
# Aggregation pipeline - count of each tag
pipeline = [
    # Project only the 'Tags' field
    {
        "$project": {
            "Tags": 1
        }
    },
    # Filter out documents where 'Tags' is missing or is not an array
    {
        "$match": {
            "Tags": {"$exists": True, "$type": "array"}
        }
    },
    # Unwind the 'Tags' array to create a document for each tag
    {
        "$unwind": "$Tags"
    },
    # Group by tag and count occurrences
    {
        "$group": {
            "_id": "$Tags",
            "count": {"$sum": 1}
        }
    },
    # Sort by count in descending order
    {
        "$sort": {"count": -1}
    },
    # Limit to the top 1000 tags
    {
        "$limit": 1000
    }
]

# %%
# Execute the aggregation query
docs = list(col.aggregate(pipeline))

# %%
import boto3
from botocore.exceptions import ClientError

# Initialize a DynamoDB client
dynamodb = boto3.resource('dynamodb', aws_access_key_id = config['ACCESS_ID'], aws_secret_access_key=config['SECRET_KEY'],region_name='us-east-1')

# Reference to your DynamoDB table
table_name = "final"
table = dynamodb.Table(table_name)

# %% [markdown]
# ### Careful running the AWS code, double check if the table is cleared when uploading the 1000 top tags

# %%
# delete and recreate table - mimics clearing the data for new calculated content

# Delete the table
table.delete()
print(f"Table '{table_name}' deleted.")

# Wait for the table to be deleted
table.wait_until_not_exists()

# Recreate the table (example schema)
new_table = dynamodb.create_table(
    TableName=table_name,
    KeySchema=[{'AttributeName': 'tag', 'KeyType': 'HASH'}],
    AttributeDefinitions=[{'AttributeName': 'tag', 'AttributeType': 'S'}],
    ProvisionedThroughput={'ReadCapacityUnits': 5, 'WriteCapacityUnits': 5}
)

# Wait for the table to be created
new_table.wait_until_exists()
print(f"Table '{table_name}' recreated.")

# %%
print(len(docs))
print(docs)
# upload precalculated top 1000 records into dynamoDB
for tag in docs:
    tag_id = tag["_id"]
    try:
        table.put_item(Item={"tag": tag_id})
        print(f"Uploaded tag: {tag_id}")
    except ClientError as e:
        print(f"Error uploading tag: {e}")
# Out:
# 1000
# [{'_id': 'javascript', 'count': 2496567}, {'_id': 'python', 'count': 2138942}, {'_id': 'java', 'count': 1898054}, {'_id': 'c#', 'count': 1592815}, {'_id': 'php', 'count': 1458812}, {'_id': 'android', 'count': 1404681}, {'_id': 'html', 'count': 1174530}, {'_id': 'jquery', 'count': 1033935}, {'_id': 'c++', 'count': 794407}, {'_id': 'css', 'count': 792766}, {'_id': 'ios', 'count': 681166}, {'_id': 'sql', 'count': 661392}, {'_id': 'mysql', 'count': 660061}, {'_id': 'r', 'count': 490741}, {'_id': 'node.js', 'count': 462679}, {'_id': 'reactjs', 'count': 456594}, {'_id': 'arrays', 'count': 413135}, {'_id': 'c', 'count': 396698}, {'_id': 'asp.net', 'count': 373010}, {'_id': 'json', 'count': 356195}, {'_id': 'python-3.x', 'count': 338362}, {'_id': 'ruby-on-rails', 'count': 336846}, {'_id': '.net', 'count': 331660}, {'_id': 'sql-server', 'count': 330256}, {'_id': 'swift', 'count': 327523}, {'_id': 'django', 'count': 306986}, {'_id': 'angular', 'count': 296194}, {'_id': 'objective-c', 'count': 292498}, {'_id': 'pandas', 'count': 279740}, {'_id': 'excel', 'count': 279248}, {'_id': 'angularjs', 'count': 262749}, {'_id': 'regex', 'count': 258051}, {'_id': 'ruby', 'count': 227954}, {'_id': 'linux', 'count': 224667}, {'_id': 'ajax', 'count': 221746}, {'_id': 'iphone', 'count': 221460}, {'_id': 'typescript', 'count': 216375}, {'_id': 'xml', 'count': 213133}, {'_id': 'vba', 'count': 209478}, {'_id': 'spring', 'count': 206982}, {'_id': 'laravel', 'count': 206199}, {'_id': 'asp.net-mvc', 'count': 200623}, {'_id': 'database', 'count': 193002}, {'_id': 'wordpress', 'count': 190601}, {'_id': 'string', 'count': 182644}, {'_id': 'mongodb', 'count': 173454}, {'_id': 'postgresql', 'count': 169838}, {'_id': 'wpf', 'count': 168432}, {'_id': 'windows', 'count': 165438}, {'_id': 'flutter', 'count': 162762}, {'_id': 'xcode', 'count': 158215}, {'_id': 'bash', 'count': 153018}, {'_id': 'amazon-web-services', 'count': 152395}, {'_id': 'oracle', 'count': 148847}, {'_id': 'git', 'count': 148820}, {'_id': 'dataframe', 'count': 141651}, {'_id': 'firebase', 'count': 139988}, {'_id': 'spring-boot', 'count': 139910}, {'_id': 'list', 'count': 139840}, {'_id': 'vb.net', 'count': 139438}, {'_id': 'multithreading', 'count': 138589}, {'_id': 'azure', 'count': 131741}, {'_id': 'react-native', 'count': 131567}, {'_id': 'docker', 'count': 130528}, {'_id': 'eclipse', 'count': 124584}, {'_id': 'algorithm', 'count': 118753}, {'_id': 'macos', 'count': 115693}, {'_id': 'visual-studio', 'count': 113217}, {'_id': 'image', 'count': 113069}, {'_id': 'powershell', 'count': 113003}, {'_id': 'forms', 'count': 112937}, {'_id': 'scala', 'count': 111447}, {'_id': 'numpy', 'count': 111419}, {'_id': 'function', 'count': 109727}, {'_id': 'api', 'count': 109220}, {'_id': 'vue.js', 'count': 103973}, {'_id': 'twitter-bootstrap', 'count': 102960}, {'_id': 'selenium', 'count': 102331}, {'_id': 'performance', 'count': 100600}, {'_id': 'winforms', 'count': 97967}, {'_id': 'loops', 'count': 95419}, {'_id': 'python-2.7', 'count': 95366}, {'_id': 'matlab', 'count': 94337}, {'_id': 'hibernate', 'count': 93807}, {'_id': 'sqlite', 'count': 93688}, {'_id': 'express', 'count': 93179}, {'_id': 'rest', 'count': 92215}, {'_id': 'apache', 'count': 92198}, {'_id': 'shell', 'count': 91490}, {'_id': 'entity-framework', 'count': 91181}, {'_id': 'android-studio', 'count': 89558}, {'_id': 'csv', 'count': 89149}, {'_id': 'kotlin', 'count': 88522}, {'_id': 'dart', 'count': 88252}, {'_id': 'maven', 'count': 87025}, {'_id': 'linq', 'count': 85897}, {'_id': 'facebook', 'count': 85662}, {'_id': 'qt', 'count': 85157}, {'_id': 'dictionary', 'count': 85089}, {'_id': 'unit-testing', 'count': 84303}, {'_id': 'tensorflow', 'count': 81855}, {'_id': 'file', 'count': 80891}, {'_id': 'swing', 'count': 80886}, {'_id': 'apache-spark', 'count': 80411}, {'_id': 'class', 'count': 79025}, {'_id': 'asp.net-core', 'count': 77676}, {'_id': 'sorting', 'count': 75913}, {'_id': 'date', 'count': 75822}, {'_id': 'authentication', 'count': 74273},  ...
# Uploaded tag: javascript
# Uploaded tag: python
# Uploaded tag: java
# Uploaded tag: c#
# Uploaded tag: php
# Uploaded tag: android
# Uploaded tag: html
# Uploaded tag: jquery
# Uploaded tag: c++
# Uploaded tag: css
# Uploaded tag: ios
# Uploaded tag: sql
# Uploaded tag: mysql
# Uploaded tag: r
# Uploaded tag: node.js
# Uploaded tag: reactjs
# Uploaded tag: arrays
# Uploaded tag: c
# Uploaded tag: asp.net
# Uploaded tag: json
# Uploaded tag: python-3.x
# Uploaded tag: ruby-on-rails
# Uploaded tag: .net
# Uploaded tag: sql-server
# Uploaded tag: swift
# Uploaded tag: django
# Uploaded tag: angular
# Uploaded tag: objective-c
# Uploaded tag: pandas
# Uploaded tag: excel
# Uploaded tag: angularjs
# Uploaded tag: regex
# Uploaded tag: ruby
# Uploaded tag: linux
# Uploaded tag: ajax
# Uploaded tag: iphone
# Uploaded tag: typescript
# Uploaded tag: xml
# Uploaded tag: vba
# Uploaded tag: spring
# Uploaded tag: laravel
# Uploaded tag: asp.net-mvc
# Uploaded tag: database
# Uploaded tag: wordpress
# Uploaded tag: string
# Uploaded tag: mongodb
# Uploaded tag: postgresql
# Uploaded tag: wpf
# Uploaded tag: windows
# Uploaded tag: flutter
# Uploaded tag: xcode
# Uploaded tag: bash
# Uploaded tag: amazon-web-services
# Uploaded tag: oracle
# Uploaded tag: git
# Uploaded tag: dataframe
# Uploaded tag: firebase
# Uploaded tag: spring-boot
# Uploaded tag: list
# Uploaded tag: vb.net
# Uploaded tag: multithreading
# Uploaded tag: azure
# Uploaded tag: react-native
# Uploaded tag: docker
# Uploaded tag: eclipse
# Uploaded tag: algorithm
# Uploaded tag: macos
# Uploaded tag: visual-studio
# Uploaded tag: image
# Uploaded tag: powershell
# Uploaded tag: forms
# Uploaded tag: scala
# Uploaded tag: numpy
# Uploaded tag: function
# Uploaded tag: api
# Uploaded tag: vue.js
# Uploaded tag: twitter-bootstrap
# Uploaded tag: selenium
# Uploaded tag: performance
# Uploaded tag: winforms
# Uploaded tag: loops
# Uploaded tag: python-2.7
# Uploaded tag: matlab
# Uploaded tag: hibernate
# Uploaded tag: sqlite
# Uploaded tag: express
# Uploaded tag: rest
# Uploaded tag: apache
# Uploaded tag: shell
# Uploaded tag: entity-framework
# Uploaded tag: android-studio
# Uploaded tag: csv
# Uploaded tag: kotlin
# Uploaded tag: dart
# Uploaded tag: maven
# Uploaded tag: linq
# Uploaded tag: facebook
# Uploaded tag: qt
# Uploaded tag: dictionary
# Uploaded tag: unit-testing
# Uploaded tag: tensorflow
# Uploaded tag: file
# Uploaded tag: swing
# Uploaded tag: apache-spark
# Uploaded tag: class
# Uploaded tag: asp.net-core
# Uploaded tag: sorting
# Uploaded tag: date
# Uploaded tag: authentication
# Uploaded tag: unity-game-engine
# Uploaded tag: symfony
# Uploaded tag: .htaccess
# Uploaded tag: tsql
# Uploaded tag: google-chrome
# Uploaded tag: opencv
# Uploaded tag: for-loop
# Uploaded tag: matplotlib
# Uploaded tag: datetime
# Uploaded tag: codeigniter
# Uploaded tag: go
# Uploaded tag: perl
# Uploaded tag: http
# Uploaded tag: validation
# Uploaded tag: sockets
# Uploaded tag: google-maps
# Uploaded tag: object
# Uploaded tag: uitableview
# Uploaded tag: xaml
# Uploaded tag: cordova
# Uploaded tag: oop
# Uploaded tag: if-statement
# Uploaded tag: ubuntu
# Uploaded tag: web-services
# Uploaded tag: android-layout
# Uploaded tag: email
# Uploaded tag: spring-mvc
# Uploaded tag: elasticsearch
# Uploaded tag: ms-access
# Uploaded tag: parsing
# Uploaded tag: user-interface
# Uploaded tag: c++11
# Uploaded tag: ruby-on-rails-3
# Uploaded tag: kubernetes
# Uploaded tag: pointers
# Uploaded tag: security
# Uploaded tag: github
# Uploaded tag: visual-studio-code
# Uploaded tag: machine-learning
# Uploaded tag: templates
# Uploaded tag: nginx
# Uploaded tag: sql-server-2008
# Uploaded tag: variables
# Uploaded tag: ggplot2
# Uploaded tag: batch-file
# Uploaded tag: exception
# Uploaded tag: flask
# Uploaded tag: listview
# Uploaded tag: selenium-webdriver
# Uploaded tag: jsp
# Uploaded tag: google-apps-script
# Uploaded tag: google-sheets
# Uploaded tag: debugging
# Uploaded tag: jpa
# Uploaded tag: delphi
# Uploaded tag: wcf
# Uploaded tag: haskell
# Uploaded tag: pdf
# Uploaded tag: tkinter
# Uploaded tag: asynchronous
# Uploaded tag: gradle
# Uploaded tag: xamarin
# Uploaded tag: ssl
# Uploaded tag: jenkins
# Uploaded tag: amazon-s3
# Uploaded tag: testing
# Uploaded tag: web-scraping
# Uploaded tag: npm
# Uploaded tag: generics
# Uploaded tag: ionic-framework
# Uploaded tag: web
# Uploaded tag: unix
# Uploaded tag: google-app-engine
# Uploaded tag: visual-studio-2010
# Uploaded tag: recursion
# Uploaded tag: mongoose
# Uploaded tag: google-cloud-platform
# Uploaded tag: android-fragments
# Uploaded tag: session
# Uploaded tag: animation
# Uploaded tag: hadoop
# Uploaded tag: heroku
# Uploaded tag: laravel-5
# Uploaded tag: curl
# Uploaded tag: math
# Uploaded tag: url
# Uploaded tag: .net-core
# Uploaded tag: svg
# Uploaded tag: join
# Uploaded tag: django-models
# Uploaded tag: tomcat
# Uploaded tag: assembly
# Uploaded tag: intellij-idea
# Uploaded tag: asp.net-mvc-4
# Uploaded tag: redirect
# Uploaded tag: webpack
# Uploaded tag: keras
# Uploaded tag: inheritance
# Uploaded tag: winapi
# Uploaded tag: image-processing
# Uploaded tag: actionscript-3
# Uploaded tag: dom
# Uploaded tag: google-cloud-firestore
# Uploaded tag: logging
# Uploaded tag: matrix
# Uploaded tag: post
# Uploaded tag: gcc
# Uploaded tag: button
# Uploaded tag: firebase-realtime-database
# Uploaded tag: jquery-ui
# Uploaded tag: cocoa
# Uploaded tag: d3.js
# Uploaded tag: internet-explorer
# Uploaded tag: xpath
# Uploaded tag: iis
# Uploaded tag: firefox
# Uploaded tag: optimization
# Uploaded tag: asp.net-mvc-3
# Uploaded tag: select
# Uploaded tag: pyspark
# Uploaded tag: networking
# Uploaded tag: xslt
# Uploaded tag: opengl
# Uploaded tag: magento
# Uploaded tag: events
# Uploaded tag: javafx
# Uploaded tag: caching
# Uploaded tag: asp.net-web-api
# Uploaded tag: plot
# Uploaded tag: search
# Uploaded tag: rust
# Uploaded tag: ruby-on-rails-4
# Uploaded tag: encryption
# Uploaded tag: stored-procedures
# Uploaded tag: amazon-ec2
# Uploaded tag: audio
# Uploaded tag: canvas
# Uploaded tag: jsf
# Uploaded tag: memory
# Uploaded tag: dplyr
# Uploaded tag: redux
# Uploaded tag: multidimensional-array
# Uploaded tag: random
# Uploaded tag: flash
# Uploaded tag: facebook-graph-api
# Uploaded tag: vector
# Uploaded tag: input
# Uploaded tag: ipad
# Uploaded tag: cocoa-touch
# Uploaded tag: cookies
# Uploaded tag: arraylist
# Uploaded tag: xamarin.forms
# Uploaded tag: video
# Uploaded tag: swiftui
# Uploaded tag: indexing
# Uploaded tag: model-view-controller
# Uploaded tag: servlets
# Uploaded tag: data-structures
# Uploaded tag: mod-rewrite
# Uploaded tag: serialization
# Uploaded tag: jdbc
# Uploaded tag: razor
# Uploaded tag: routes
# Uploaded tag: woocommerce
# Uploaded tag: awk
# Uploaded tag: iframe
# Uploaded tag: beautifulsoup
# Uploaded tag: design-patterns
# Uploaded tag: filter
# Uploaded tag: cakephp
# Uploaded tag: text
# Uploaded tag: next.js
# Uploaded tag: visual-c++
# Uploaded tag: apache-kafka
# Uploaded tag: django-rest-framework
# Uploaded tag: android-intent
# Uploaded tag: mobile
# Uploaded tag: methods
# Uploaded tag: struct
# Uploaded tag: aws-lambda
# Uploaded tag: grails
# Uploaded tag: ecmascript-6
# Uploaded tag: mvvm
# Uploaded tag: checkbox
# Uploaded tag: groovy
# Uploaded tag: ssh
# Uploaded tag: excel-formula
# Uploaded tag: docker-compose
# Uploaded tag: lambda
# Uploaded tag: time
# Uploaded tag: jakarta-ee
# Uploaded tag: azure-devops
# Uploaded tag: android-recyclerview
# Uploaded tag: installation
# Uploaded tag: meteor
# Uploaded tag: google-chrome-extension
# Uploaded tag: core-data
# Uploaded tag: sharepoint
# Uploaded tag: android-activity
# Uploaded tag: react-hooks
# Uploaded tag: bootstrap-4
# Uploaded tag: activerecord
# Uploaded tag: graph
# Uploaded tag: sed
# Uploaded tag: plsql
# Uploaded tag: types
# Uploaded tag: shiny
# Uploaded tag: file-upload
# Uploaded tag: vim
# Uploaded tag: spring-security
# Uploaded tag: scikit-learn
# Uploaded tag: replace
# Uploaded tag: junit
# Uploaded tag: websocket
# Uploaded tag: soap
# Uploaded tag: boost
# Uploaded tag: silverlight
# Uploaded tag: memory-management
# Uploaded tag: group-by
# Uploaded tag: dynamic
# Uploaded tag: import
# Uploaded tag: deep-learning
# Uploaded tag: sass
# Uploaded tag: cmake
# Uploaded tag: eloquent
# Uploaded tag: gridview
# Uploaded tag: svn
# Uploaded tag: layout
# Uploaded tag: error-handling
# Uploaded tag: browser
# Uploaded tag: apache-spark-sql
# Uploaded tag: cmd
# Uploaded tag: charts
# Uploaded tag: async-await
# Uploaded tag: vuejs2
# Uploaded tag: while-loop
# Uploaded tag: dependency-injection
# Uploaded tag: view
# Uploaded tag: ffmpeg
# Uploaded tag: c#-4.0
# Uploaded tag: dll
# Uploaded tag: highcharts
# Uploaded tag: foreach
# Uploaded tag: deployment
# Uploaded tag: plugins
# Uploaded tag: reporting-services
# Uploaded tag: twitter
# Uploaded tag: google-maps-api-3
# Uploaded tag: mysqli
# Uploaded tag: makefile
# Uploaded tag: extjs
# Uploaded tag: https
# Uploaded tag: unicode
# Uploaded tag: server
# Uploaded tag: reflection
# Uploaded tag: merge
# Uploaded tag: redis
# Uploaded tag: google-bigquery
# Uploaded tag: jupyter-notebook
# Uploaded tag: netbeans
# Uploaded tag: split
# Uploaded tag: encoding
# Uploaded tag: apache-flex
# Uploaded tag: database-design
# Uploaded tag: ember.js
# Uploaded tag: terminal
# Uploaded tag: pdo
# Uploaded tag: collections
# Uploaded tag: hash
# Uploaded tag: axios
# Uploaded tag: django-views
# Uploaded tag: data-binding
# Uploaded tag: tcp
# Uploaded tag: oauth-2.0
# Uploaded tag: command-line
# Uploaded tag: react-redux
# Uploaded tag: automation
# Uploaded tag: printing
# Uploaded tag: service
# Uploaded tag: visual-studio-2012
# Uploaded tag: build
# Uploaded tag: pip
# Uploaded tag: java-8
# Uploaded tag: html-table
# Uploaded tag: sqlalchemy
# Uploaded tag: ansible
# Uploaded tag: jquery-mobile
# Uploaded tag: parameters
# Uploaded tag: neo4j
# Uploaded tag: jestjs
# Uploaded tag: web-applications
# Uploaded tag: promise
# Uploaded tag: webview
# Uploaded tag: module
# Uploaded tag: concurrency
# Uploaded tag: uwp
# Uploaded tag: enums
# Uploaded tag: utf-8
# Uploaded tag: datatable
# Uploaded tag: spring-data-jpa
# Uploaded tag: lua
# Uploaded tag: drop-down-menu
# Uploaded tag: hive
# Uploaded tag: pytorch
# Uploaded tag: tfs
# Uploaded tag: outlook
# Uploaded tag: material-ui
# Uploaded tag: scroll
# Uploaded tag: flexbox
# Uploaded tag: colors
# Uploaded tag: python-requests
# Uploaded tag: twitter-bootstrap-3
# Uploaded tag: count
# Uploaded tag: syntax
# Uploaded tag: firebase-authentication
# Uploaded tag: parallel-processing
# Uploaded tag: google-analytics
# Uploaded tag: file-io
# Uploaded tag: ssis
# Uploaded tag: scipy
# Uploaded tag: paypal
# Uploaded tag: fonts
# Uploaded tag: gwt
# Uploaded tag: constructor
# Uploaded tag: ms-word
# Uploaded tag: backbone.js
# Uploaded tag: three.js
# Uploaded tag: entity-framework-core
# Uploaded tag: socket.io
# Uploaded tag: datatables
# Uploaded tag: graphql
# Uploaded tag: solr
# Uploaded tag: cassandra
# Uploaded tag: url-rewriting
# Uploaded tag: zend-framework
# Uploaded tag: graphics
# Uploaded tag: rxjs
# Uploaded tag: drupal
# Uploaded tag: knockout.js
# Uploaded tag: datagridview
# Uploaded tag: oracle11g
# Uploaded tag: discord
# Uploaded tag: memory-leaks
# Uploaded tag: oauth
# Uploaded tag: compiler-errors
# Uploaded tag: pygame
# Uploaded tag: react-router
# Uploaded tag: django-forms
# Uploaded tag: neural-network
# Uploaded tag: nlp
# Uploaded tag: interface
# Uploaded tag: windows-phone-7
# Uploaded tag: parse-platform
# Uploaded tag: visual-studio-2015
# Uploaded tag: casting
# Uploaded tag: linked-list
# Uploaded tag: triggers
# Uploaded tag: google-api
# Uploaded tag: proxy
# Uploaded tag: timer
# Uploaded tag: directory
# Uploaded tag: cron
# Uploaded tag: django-templates
# Uploaded tag: primefaces
# Uploaded tag: path
# Uploaded tag: orm
# Uploaded tag: arduino
# Uploaded tag: angular-material
# Uploaded tag: push-notification
# Uploaded tag: conditional-statements
# Uploaded tag: model
# Uploaded tag: jar
# Uploaded tag: functional-programming
# Uploaded tag: visual-studio-2013
# Uploaded tag: xamarin.android
# Uploaded tag: jmeter
# Uploaded tag: uiview
# Uploaded tag: vbscript
# Uploaded tag: hyperlink
# Uploaded tag: swift3
# Uploaded tag: sql-server-2005
# Uploaded tag: download
# Uploaded tag: windows-phone-8
# Uploaded tag: rspec
# Uploaded tag: process
# Uploaded tag: properties
# Uploaded tag: combobox
# Uploaded tag: callback
# Uploaded tag: configuration
# Uploaded tag: scrapy
# Uploaded tag: powerbi
# Uploaded tag: emacs
# Uploaded tag: safari
# Uploaded tag: pagination
# Uploaded tag: scripting
# Uploaded tag: clojure
# Uploaded tag: angularjs-directive
# Uploaded tag: nhibernate
# Uploaded tag: permissions
# Uploaded tag: io
# Uploaded tag: scope
# Uploaded tag: terraform
# Uploaded tag: raspberry-pi
# Uploaded tag: request
# Uploaded tag: playframework
# Uploaded tag: google-cloud-functions
# Uploaded tag: responsive-design
# Uploaded tag: linux-kernel
# Uploaded tag: mongodb-query
# Uploaded tag: dns
# Uploaded tag: gitlab
# Uploaded tag: doctrine-orm
# Uploaded tag: azure-active-directory
# Uploaded tag: binding
# Uploaded tag: compilation
# Uploaded tag: bluetooth
# Uploaded tag: get
# Uploaded tag: version-control
# Uploaded tag: sql-server-2012
# Uploaded tag: reference
# Uploaded tag: jwt
# Uploaded tag: architecture
# Uploaded tag: 3d
# Uploaded tag: discord.js
# Uploaded tag: pyqt
# Uploaded tag: rubygems
# Uploaded tag: x86
# Uploaded tag: f#
# Uploaded tag: yii
# Uploaded tag: kendo-ui
# Uploaded tag: package
# Uploaded tag: autocomplete
# Uploaded tag: datepicker
# Uploaded tag: tree
# Uploaded tag: controller
# Uploaded tag: xamarin.ios
# Uploaded tag: pycharm
# Uploaded tag: phpmyadmin
# Uploaded tag: grep
# Uploaded tag: jackson
# Uploaded tag: static
# Uploaded tag: nested
# Uploaded tag: uiviewcontroller
# Uploaded tag: datagrid
# Uploaded tag: statistics
# Uploaded tag: openssl
# Uploaded tag: null
# Uploaded tag: active-directory
# Uploaded tag: webforms
# Uploaded tag: transactions
# Uploaded tag: nullpointerexception
# Uploaded tag: notifications
# Uploaded tag: youtube
# Uploaded tag: jsf-2
# Uploaded tag: menu
# Uploaded tag: bitmap
# Uploaded tag: duplicates
# Uploaded tag: visual-studio-2008
# Uploaded tag: asp.net-mvc-5
# Uploaded tag: stream
# Uploaded tag: android-listview
# Uploaded tag: mocking
# Uploaded tag: sas
# Uploaded tag: computer-vision
# Uploaded tag: yii2
# Uploaded tag: ant
# Uploaded tag: discord.py
# Uploaded tag: stl
# Uploaded tag: sum
# Uploaded tag: hashmap
# Uploaded tag: jboss
# Uploaded tag: css-selectors
# Uploaded tag: joomla
# Uploaded tag: character-encoding
# Uploaded tag: devise
# Uploaded tag: yaml
# Uploaded tag: time-series
# Uploaded tag: electron
# Uploaded tag: floating-point
# Uploaded tag: msbuild
# Uploaded tag: sdk
# Uploaded tag: azure-functions
# Uploaded tag: linq-to-sql
# Uploaded tag: background
# Uploaded tag: cryptography
# Uploaded tag: dockerfile
# Uploaded tag: ios7
# Uploaded tag: binary
# Uploaded tag: camera
# Uploaded tag: google-drive-api
# Uploaded tag: anaconda
# Uploaded tag: onclick
# Uploaded tag: android-asynctask
# Uploaded tag: pyqt5
# Uploaded tag: navigation
# Uploaded tag: laravel-4
# Uploaded tag: iterator
# Uploaded tag: insert
# Uploaded tag: frontend
# Uploaded tag: uicollectionview
# Uploaded tag: tabs
# Uploaded tag: multiprocessing
# Uploaded tag: ftp
# Uploaded tag: cuda
# Uploaded tag: textview
# Uploaded tag: expo
# Uploaded tag: upload
# Uploaded tag: coldfusion
# Uploaded tag: asp.net-core-mvc
# Uploaded tag: rabbitmq
# Uploaded tag: xsd
# Uploaded tag: opengl-es
# Uploaded tag: selenium-chromedriver
# Uploaded tag: console
# Uploaded tag: xml-parsing
# Uploaded tag: leaflet
# Uploaded tag: linker
# Uploaded tag: mariadb
# Uploaded tag: localization
# Uploaded tag: plotly
# Uploaded tag: calendar
# Uploaded tag: continuous-integration
# Uploaded tag: amazon-dynamodb
# Uploaded tag: operating-system
# Uploaded tag: formatting
# Uploaded tag: json.net
# Uploaded tag: android-ndk
# Uploaded tag: kivy
# Uploaded tag: timestamp
# Uploaded tag: header
# Uploaded tag: environment-variables
# Uploaded tag: type-conversion
# Uploaded tag: mockito
# Uploaded tag: macros
# Uploaded tag: integer
# Uploaded tag: data.table
# Uploaded tag: prolog
# Uploaded tag: jasmine
# Uploaded tag: segmentation-fault
# Uploaded tag: drag-and-drop
# Uploaded tag: char
# Uploaded tag: sprite-kit
# Uploaded tag: flutter-layout
# Uploaded tag: cors
# Uploaded tag: crash
# Uploaded tag: jquery-plugins
# Uploaded tag: itext
# Uploaded tag: nosql
# Uploaded tag: annotations
# Uploaded tag: automated-tests
# Uploaded tag: attributes
# Uploaded tag: mfc
# Uploaded tag: geometry
# Uploaded tag: android-gradle-plugin
# Uploaded tag: format
# Uploaded tag: fortran
# Uploaded tag: visual-studio-2017
# Uploaded tag: gulp
# Uploaded tag: dependencies
# Uploaded tag: event-handling
# Uploaded tag: microsoft-graph-api
# Uploaded tag: textbox
# Uploaded tag: db2
# Uploaded tag: libgdx
# Uploaded tag: xampp
# Uploaded tag: keyboard
# Uploaded tag: uiscrollview
# Uploaded tag: centos
# Uploaded tag: jenkins-pipeline
# Uploaded tag: crystal-reports
# Uploaded tag: dom-events
# Uploaded tag: synchronization
# Uploaded tag: odoo
# Uploaded tag: firebase-cloud-messaging
# Uploaded tag: geolocation
# Uploaded tag: namespaces
# Uploaded tag: sequelize.js
# Uploaded tag: android-emulator
# Uploaded tag: com
# Uploaded tag: aggregation-framework
# Uploaded tag: timezone
# Uploaded tag: ionic2
# Uploaded tag: mapreduce
# Uploaded tag: webdriver
# Uploaded tag: arm
# Uploaded tag: windows-10
# Uploaded tag: jvm
# Uploaded tag: android-edittext
# Uploaded tag: dialog
# Uploaded tag: numbers
# Uploaded tag: html5-canvas
# Uploaded tag: subprocess
# Uploaded tag: garbage-collection
# Uploaded tag: postman
# Uploaded tag: wso2
# Uploaded tag: xmlhttprequest
# Uploaded tag: lucene
# Uploaded tag: rotation
# Uploaded tag: fetch
# Uploaded tag: julia
# Uploaded tag: concatenation
# Uploaded tag: set
# Uploaded tag: sql-update
# Uploaded tag: widget
# Uploaded tag: radio-button
# Uploaded tag: modal-dialog
# Uploaded tag: chart.js
# Uploaded tag: doctrine
# Uploaded tag: tuples
# Uploaded tag: smtp
# Uploaded tag: ios5
# Uploaded tag: grid
# Uploaded tag: swagger
# Uploaded tag: listbox
# Uploaded tag: spring-data
# Uploaded tag: http-headers
# Uploaded tag: nuxt.js
# Uploaded tag: sonarqube
# Uploaded tag: blazor
# Uploaded tag: switch-statement
# Uploaded tag: frameworks
# Uploaded tag: boolean
# Uploaded tag: eclipse-plugin
# Uploaded tag: qml
# Uploaded tag: uikit
# Uploaded tag: compiler-construction
# Uploaded tag: ldap
# Uploaded tag: initialization
# Uploaded tag: internationalization
# Uploaded tag: return
# Uploaded tag: components
# Uploaded tag: apache-camel
# Uploaded tag: serial-port
# Uploaded tag: nuget
# Uploaded tag: google-play
# Uploaded tag: asp-classic
# Uploaded tag: tags
# Uploaded tag: java-stream
# Uploaded tag: azure-web-app-service
# Uploaded tag: struts2
# Uploaded tag: uinavigationcontroller
# Uploaded tag: youtube-api
# Uploaded tag: protractor
# Uploaded tag: sql-server-2008-r2
# Uploaded tag: dataset
# Uploaded tag: delegates
# Uploaded tag: subquery
# Uploaded tag: stripe-payments
# Uploaded tag: uibutton
# Uploaded tag: network-programming
# Uploaded tag: gdb
# Uploaded tag: foreign-keys
# Uploaded tag: copy
# Uploaded tag: pivot
# Uploaded tag: nestjs
# Uploaded tag: label
# Uploaded tag: find
# Uploaded tag: append
# Uploaded tag: base64
# Uploaded tag: jaxb
# Uploaded tag: queue
# Uploaded tag: autolayout
# Uploaded tag: arguments
# Uploaded tag: containers
# Uploaded tag: windows-7
# Uploaded tag: azure-pipelines
# Uploaded tag: latex
# Uploaded tag: zip
# Uploaded tag: composer-php
# Uploaded tag: entity-framework-6
# Uploaded tag: popup
# Uploaded tag: migration
# Uploaded tag: jqgrid
# Uploaded tag: cucumber
# Uploaded tag: stack
# Uploaded tag: ide
# Uploaded tag: android-viewpager
# Uploaded tag: google-sheets-formula
# Uploaded tag: vb6
# Uploaded tag: iteration
# Uploaded tag: uiwebview
# Uploaded tag: ios4
# Uploaded tag: passwords
# Uploaded tag: google-cloud-storage
# Uploaded tag: hover
# Uploaded tag: command
# Uploaded tag: uiimageview
# Uploaded tag: udp
# Uploaded tag: vuejs3
# Uploaded tag: gmail
# Uploaded tag: twig
# Uploaded tag: conv-neural-network
# Uploaded tag: range
# Uploaded tag: c++17
# Uploaded tag: ssl-certificate
# Uploaded tag: vue-component
# Uploaded tag: jersey
# Uploaded tag: ionic3
# Uploaded tag: angular-ui-router
# Uploaded tag: g++
# Uploaded tag: embedded
# Uploaded tag: salesforce
# Uploaded tag: r-markdown
# Uploaded tag: windows-8
# Uploaded tag: snowflake-cloud-data-platform
# Uploaded tag: user-controls
# Uploaded tag: gps
# Uploaded tag: local-storage
# Uploaded tag: constants
# Uploaded tag: cocos2d-iphone
# Uploaded tag: bots
# Uploaded tag: wix
# Uploaded tag: authorization
# Uploaded tag: connection
# Uploaded tag: compare
# Uploaded tag: polymorphism
# Uploaded tag: slider
# Uploaded tag: django-admin
# Uploaded tag: localhost
# Uploaded tag: debian
# Uploaded tag: ado.net
# Uploaded tag: twilio
# Uploaded tag: mono
# Uploaded tag: time-complexity
# Uploaded tag: save
# Uploaded tag: clang
# Uploaded tag: jframe
# Uploaded tag: admob
# Uploaded tag: phpunit
# Uploaded tag: certificate
# Uploaded tag: sbt
# Uploaded tag: imageview
# Uploaded tag: airflow
# Uploaded tag: python-imaging-library
# Uploaded tag: drupal-7
# Uploaded tag: coffeescript
# Uploaded tag: gson
# Uploaded tag: output
# Uploaded tag: pipe
# Uploaded tag: include
# Uploaded tag: cypher
# Uploaded tag: int
# Uploaded tag: fullcalendar
# Uploaded tag: mapping
# Uploaded tag: java-native-interface
# Uploaded tag: babeljs
# Uploaded tag: apache-poi
# Uploaded tag: web-crawler
# Uploaded tag: timeout
# Uploaded tag: location
# Uploaded tag: hex
# Uploaded tag: tidyverse
# Uploaded tag: erlang
# Uploaded tag: log4j
# Uploaded tag: pytest
# Uploaded tag: filesystems
# Uploaded tag: cypress
# Uploaded tag: export
# Uploaded tag: substring
# Uploaded tag: runtime-error
# Uploaded tag: iis-7
# Uploaded tag: icons
# Uploaded tag: google-oauth
# Uploaded tag: observable
# Uploaded tag: storyboard
# Uploaded tag: azure-sql-database
# Uploaded tag: window
# Uploaded tag: regression
# Uploaded tag: telerik
# Uploaded tag: key
# Uploaded tag: ruby-on-rails-5
# Uploaded tag: elixir
# Uploaded tag: odbc
# Uploaded tag: maps
# Uploaded tag: treeview
# Uploaded tag: seaborn
# Uploaded tag: syntax-error
# Uploaded tag: click
# Uploaded tag: printf
# Uploaded tag: jinja2
# Uploaded tag: typo3
# Uploaded tag: realm
# Uploaded tag: cocoapods
# Uploaded tag: ios8
# Uploaded tag: ip
# Uploaded tag: wsdl
# Uploaded tag: wordpress-theming
# Uploaded tag: signalr
# Uploaded tag: logic
# Uploaded tag: resources
# Uploaded tag: ckeditor
# Uploaded tag: kernel
# Uploaded tag: command-line-interface
# Uploaded tag: thread-safety
# Uploaded tag: dojo
# Uploaded tag: bluetooth-lowenergy
# Uploaded tag: botframework
# Uploaded tag: uiimage
# Uploaded tag: in-app-purchase
# Uploaded tag: resize
# Uploaded tag: position
# Uploaded tag: amazon-elastic-beanstalk
# Uploaded tag: styles
# Uploaded tag: cloud
# Uploaded tag: actionscript
# Uploaded tag: imagemagick
# Uploaded tag: android-jetpack-compose
# Uploaded tag: compression
# Uploaded tag: thymeleaf
# Uploaded tag: gruntjs
# Uploaded tag: malloc
# Uploaded tag: angularjs-ng-repeat
# Uploaded tag: cross-browser
# Uploaded tag: repository
# Uploaded tag: where-clause
# Uploaded tag: state
# Uploaded tag: google-visualization
# Uploaded tag: pattern-matching
# Uploaded tag: data-science
# Uploaded tag: angularjs-scope
# Uploaded tag: max
# Uploaded tag: windows-services
# Uploaded tag: build.gradle
# Uploaded tag: microservices
# Uploaded tag: android-actionbar
# Uploaded tag: escaping
# Uploaded tag: swift2
# Uploaded tag: webrtc
# Uploaded tag: celery
# Uploaded tag: closures
# Uploaded tag: pthreads
# Uploaded tag: .net-4.0
# Uploaded tag: asp.net-identity
# Uploaded tag: jquery-selectors
# Uploaded tag: pandas-groupby
# Uploaded tag: windows-installer
# Uploaded tag: jsx
# Uploaded tag: constraints
# Uploaded tag: global-variables
# Uploaded tag: locking
# Uploaded tag: github-actions
# Uploaded tag: ios6
# Uploaded tag: gpu
# Uploaded tag: applescript
# Uploaded tag: try-catch
# Uploaded tag: vuetify.js
# Uploaded tag: office365
# Uploaded tag: http-post
# Uploaded tag: windows-runtime
# Uploaded tag: zend-framework2
# Uploaded tag: google-chrome-devtools
# Uploaded tag: qt5
# Uploaded tag: many-to-many
# Uploaded tag: web-config
# Uploaded tag: match
# Uploaded tag: alignment
# Uploaded tag: logstash
# Uploaded tag: vagrant
# Uploaded tag: retrofit
# Uploaded tag: markdown
# Uploaded tag: mocha.js
# Uploaded tag: uitextfield
# Uploaded tag: singleton
# Uploaded tag: jtable
# Uploaded tag: video-streaming
# Uploaded tag: material-design
# Uploaded tag: ef-code-first
# Uploaded tag: internet-explorer-8
# Uploaded tag: sharepoint-2010
# Uploaded tag: shopify
# Uploaded tag: jasper-reports
# Uploaded tag: asp.net-mvc-2
# Uploaded tag: gtk
# Uploaded tag: testng
# Uploaded tag: sh
# Uploaded tag: c++14
# Uploaded tag: amazon-redshift
# Uploaded tag: operator-overloading
# Uploaded tag: blackberry
# Uploaded tag: task
# Uploaded tag: controls
# Uploaded tag: broadcastreceiver
# Uploaded tag: react-navigation
# Uploaded tag: language-agnostic
# Uploaded tag: bitbucket
# Uploaded tag: azure-blob-storage
# Uploaded tag: artificial-intelligence
# Uploaded tag: polymer
# Uploaded tag: hdfs
# Uploaded tag: double
# Uploaded tag: mercurial

# %%
# mockup of code to be used in javascript server query

# retrieve list of tags from DynamoDB
response = table.scan(ProjectionExpression='tag')
tags_list = [item['tag'] for item in response['Items']]
print(tags_list)
print(len(tags_list))
# Out:
# ['export', 'angularjs-directive', 'ssis', 'windows-runtime', 'function', 'ffmpeg', 'stripe-payments', 'paypal', 'retrofit', 'global-variables', 'opencv', 'centos', 'drag-and-drop', 'sonarqube', 'codeigniter', 'winapi', 'binary', 'in-app-purchase', 'maps', 'android-listview', 'optimization', 'typescript', 'angularjs-ng-repeat', 'filesystems', 'uitextfield', 'webpack', 'sprite-kit', 'jsx', 'excel', 'gradle', 'nuget', 'pyqt5', 'terminal', 'active-directory', 'wordpress-theming', 'salesforce', 'mfc', 'repository', 'continuous-integration', 'location', 'textview', 'elasticsearch', 'vue.js', 'spring-data', 'calendar', 'ruby', 'cross-browser', 'https', 'web-config', 'uibutton', 'gpu', 'mockito', 'flutter-layout', 'android-fragments', 'xsd', 'collections', 'jpa', 'http', 'asp.net-mvc-2', 'thymeleaf', 'powerbi', 'variables', 'ef-code-first', 'heroku', 'ipad', 'timeout', 'kotlin', 'onclick', 'output', 'google-sheets-formula', 'soap', 'excel-formula', 'servlets', 'uiview', 'pagination', 'dependencies', 'floating-point', 'azure-web-app-service', 'pandas', 'gitlab', 'constructor', 'hyperlink', 'statistics', 'authentication', 'localization', 'syntax', 'ruby-on-rails', 'actionscript-3', 'uitableview', 'object', 'asp-classic', 'language-agnostic', 'angular-material', 'prolog', 'locking', 'treeview', 'performance', 'uiviewcontroller', 'joomla', 'concurrency', 'compiler-errors', 'react-router', 'apache-spark-sql', 'signalr', 'runtime-error', 'autolayout', 'ruby-on-rails-3', 'asynchronous', 'mongoose', 'uiimage', 'ssl-certificate', 'sockets', 'max', 'hive', 'multithreading', 'xslt', 'api', 'c++17', 'process', 'matplotlib', 'save', 'nlp', 'nuxt.js', 'forms', 'pyqt', 'macos', 'pycharm', 'github-actions', 'input', 'sorting', 'asp.net-core', 'jboss', 'jquery-ui', 'apache-poi', 'mongodb-query', 'expo', 'kubernetes', 'video', 'deployment', 'internet-explorer-8', 'google-drive-api', 'dictionary', 'ionic3', 'amazon-s3', 'nullpointerexception', 'machine-learning', 'xampp', 'task', 'wcf', 'build', 'jersey', 'serialization', 'callback', 'applescript', 'db2', 'modal-dialog', 'json', 'formatting', 'android-intent', 'file-io', 'file-upload', 'datepicker', 'c++11', 'containers', 'matlab', 'mod-rewrite', 'ios6', 'authorization', 'match', 'html5-canvas', 'asp.net', 'oracle11g', 'visual-studio-2013', 'debian', 'facebook', 'rabbitmq', 'initialization', 'http-post', 'debugging', 'datatable', 'phpmyadmin', 'sass', 'cmd', 'vba', 'qml', '.net-core', 'ansible', 'async-await', 'xpath', 'nginx', 'mapreduce', 'android-activity', 'windows', 'pip', 'activerecord', 'scroll', 'hash', 'rxjs', 'html-table', 'laravel-5', 'django-forms', 'position', 'responsive-design', 'utf-8', 'google-chrome-devtools', 'java-8', 'gwt', 'version-control', 'x86', 'dns', 'elixir', 'rotation', 'blazor', 'clojure', 'menu', 'dataset', 'facebook-graph-api', '.net', 'jasper-reports', 'socket.io', 'ionic-framework', 'firebase-realtime-database', 'nestjs', 'highcharts', 'jquery-mobile', 'xamarin.android', 'ado.net', 'fullcalendar', 'sql-server-2008', 'jsf-2', 'jquery-selectors', 'dll', 'url-rewriting', 'tidyverse', 'combobox', 'qt5', 'shiny', 'jwt', 'lambda', 'knockout.js', 'python-3.x', 'proxy', 'amazon-ec2', 'google-maps', 'text', 'google-chrome-extension', 'woocommerce', 'ide', 'transactions', 'import', 'datatables', 'django', 'checkbox', 'vuetify.js', 'android-ndk', 'typo3', 'dplyr', 'wsdl', 'c#', 'jdbc', 'validation', 'json.net', 'windows-services', 'encryption', 'memory-leaks', 'airflow', 'electron', 'connection', 'xcode', 'pointers', 'events', 'oracle', 'html', 'ubuntu', 'sql-server', 'session', 'timestamp', 'django-templates', 'core-data', 'styles', 'intellij-idea', 'solr', 'find', 'bots', 'ios7', 'firebase', 'visual-studio-2010', 'swift3', 'sql', 'safari', 'yii', '.htaccess', 'imageview', 'openssl', 'emacs', 'character-encoding', 'objective-c', 'templates', 'terraform', 'cucumber', 'controller', 'scikit-learn', 'where-clause', 'redirect', 'bitbucket', 'visual-studio-2017', 'database', 'spring-da ...
# 1000

# %%
# Create a sparse index on the 'Tags' field
# col.create_index('Tags', sparse=True)

# index verification
# List all indexes on the collection 
indexes = col.list_indexes()
for index in indexes:
    print(index)
# Out:
# SON([('v', 2), ('key', SON([('_id', 1)])), ('name', '_id_')])
# SON([('v', 2), ('key', SON([('ViewCount', -1)])), ('name', 'ViewCount_-1')])
# SON([('v', 2), ('key', SON([('Tags', 1)])), ('name', 'Tags_1')])
# SON([('v', 2), ('key', SON([('PostTypeId', 1), ('AcceptedAnswerId', 1), ('Id', 1), ('CreationDate', 1)])), ('name', 'PostTypeId_1_AcceptedAnswerId_1_Id_1_CreationDate_1')])

# %%
# make mongo query, compare every document to see if tags are in the tags_set
# including optimizations to increase performance and manage bandwidth:
# projection of only necessary fields (tags)
# cache dynamodb call?
# index the tags field for efficient reading of tags

# since our data is so large we want to ensure that we are offloading the bulk of the calculations onto the cluster rather than doing the calculations locally or on clientside. to do this we make use of MongoDB aggregations

# Aggregation pipeline to count tags
pipeline = [
    # Project only the 'Tags' field
    {
        "$project": {
            "Tags": 1
        }
    },
    # Filter out documents where 'Tags' is missing or is not an array
    {
        "$match": {
            "Tags": {"$exists": True, "$type": "array"}
        }
    },
    # Unwind the 'Tags' array to create a document for each tag
    {
        "$unwind": "$Tags"
    },
    # Filter to include only documents with tags in the specified list
    {
        "$match": {
            "Tags": {"$in": tags_list}
        }
    },
    # Group by tag and count occurrences
    {
        "$group": {
            "_id": "$Tags",
            "count": {"$sum": 1}
        }
    },
    # Sort by count in descending order
    {
        "$sort": {"count": -1}
    },
    # Limit to the top 1000 tags
    {
        "$limit": 1000
    }
]

top_tags = list(col.aggregate(pipeline))

# %%
print(list(top_tags))
# pretty display the resulting docs using pandas (_id: tag name, count: number of posts with that tag)
df = pd.DataFrame(top_tags)
display(df)
# Out:
# []
# Empty DataFrame
# Columns: []
# Index: []
